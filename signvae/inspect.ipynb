# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

train_data = np.load('data/bin/train.npz')
test_data  = np.load('data/bin/test.npz')

def draw_char(array):
    plt.xticks([])
    plt.yticks([])
    plt.tight_layout()
    plt.imshow(image)

for label, corpus in [
    ("Training data", train_data),
    ("Test data", test_data),
]:
    print(f"{label}:")
    print(corpus['ids'].shape[0], "tokens of size", 'x'.join(map(str,corpus['images'].shape[1:])))
    print("First 15 images:")
    for idx, char_id in enumerate(corpus['ids'][:15]):
        image = corpus['images'][char_id]
        plt.subplot(1,15,idx+1)
        draw_char(image)
    plt.show()
# Out:
# Training data:
# 30000 tokens of size 64x64
# First 15 images:
# Test data:
# 3000 tokens of size 64x64
# First 15 images:

# %%
output = torch.load(f"output/test_01_output.pt")
for key in ["gen_vae_self", "gen_vae_txr"]:
    if key not in output:
        continue
    print(f"{key}:")
    for idx in range(15):
        plt.subplot(1,15,idx+1)
        image = output[key][idx,0].detach().cpu().numpy()
        draw_char(image)
    plt.show()
# Out:
# gen_vae_self:
# gen_vae_txr:
